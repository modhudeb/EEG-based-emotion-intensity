# %% [markdown]
# # Imports

# %%
# sync drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import shutil
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pickle
import joblib

# %% [markdown]
# # Data Loading

# %%
os.listdir('drive/MyDrive/data/files/eeg-emotion')
# Out:
# ['deap_dataset.zip']

# %%
zpath = 'drive/MyDrive/data/files/eeg-emotion'
extract_path = 'drive/MyDrive/data/files/eeg-emotion/extracted'

if not os.path.exists(extract_path):
    os.makedirs(extract_path, exist_ok=True)
    shutil.unpack_archive(zpath+'/deap_dataset.zip', extract_path, format='zip')
    print(f'Successfully extracted the zip file to: {extract_path}')
else:
    print(f'The directory {extract_path} already exists. Skipping extraction.')
# Out:
# The directory drive/MyDrive/data/files/eeg-emotion/extracted already exists. Skipping extraction.
